# %%
import pandas as pd

# Nombre del archivo CSV (asegúrate de que esté en la misma carpeta)
file_name = 'N_seaice_extent_daily_v3.0.csv'

# Cargar los datos del archivo
df = pd.read_csv(file_name)

# Filtrar las filas donde la columna 'Month' es igual a 9
filtered_data = df[df['Month'] == 9]

# Mostrar los datos filtrados
print(filtered_data)
